# %% [markdown]
# Que 1. who is developed python programming ?
#
# Ans-Guido van Rossum
#
# 2. Which type of programming does Python support?
#
# ANS -Python is a multi-paradigm programming language. Object-oriented programming and structured programming are fully supported, and many of their features support functional programming and aspect-oriented programming
#
# 3. is python a case sensitive language when dealing with identifier?
#
# ANS -Yes. As you might be knowing that Python is a case-sensitive programming language. So, Python is case sensitive when dealing with Identifiers.
#
# 4. what is the correct extension of the python file
#
# ANS -.py
#
# 5. is python code is compiled or interpreted
#
# ANS- python code is interpreted
#
# 6. Name a few block of code used to define in python language
#
# ANS-Indentation is used to define a block of code in python.
#
#
# 7. State a character used to give single line4 comments in python
#
# ANS - Hash-tag (#)
#
# 8. Mention Functions which can help us to find the version of python that we are working on it
#
# ANS -The function sys. version can help us to find the version of python that we are currently working on
#
# 9. python supports the creation of anonymous function of runtime ,using a construct called
#
# Ans- Lambda
#
# 10. what does pip stand for python?
# ANS -preferred installer program
#
# 11. mention a few built in functions in python
#
# ANS-
#
# print( ) function.
#
# type( ) function.
#
# input( ) function.
#
# abs( ) function.
#
# pow( ) function.
#
# dir( ) function.
#
# sorted( ) function.
#
# max( ) function.
#
#
# 12. what is the maximum possible length of an identifier in python
#
# ANS- 79 character
#
#
# 13. what are the benefits of using python
#
# ANS -Presence of third-party modules
#
# Extensive support libraries(NumPy for numerical calculations, Pandas for data analytics, etc.)
#
# Open source and large active community base
#
# Versatile, Easy to read, learn and write
#
# User-friendly data structures
#
# High-level language
#
# Dynamically typed language(No need to mention data type based on the value assigned, it takes data type)
#
# Object-Oriented and Procedural  Programming language
#
# Portable and Interactive
#
# Ideal for prototypes – provide more functionality with less coding
#
# 14. how is memory managed in python
#
# Memory management in Python involves a private heap containing all Python objects and data structures
#
#
# 15. how to install python on windows and set path variable
#
# ANS -Install python from this link https://www.python.org/downloads/
# After this, install it on your PC. Look for the location where PYTHON has been installed on your PC using tge following command on your command prompt: cmd python.
# Then go to advanced system settings and add new variable and name it as PYTHON_NAME and paste the copied path.
# Then look for the path variable, select it's value and select edit
# Add a semicolon towards the end of the value if it's not present and then type %PYTHON_HOME%
#
# 16. is indentation required in python
#
# ANS -Yes indentation is required in python
